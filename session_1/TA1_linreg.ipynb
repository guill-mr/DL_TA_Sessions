# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Imports

# %% [markdown]
# Remember to start by running
#
# ```shell
# uv sync
# ````
#
# in the directory of the repo after cloning.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Load the necessary libraries
import numpy as np
import pandas as pd
from TA1_linreg import LinearRegressionModel
import time

# %%
# Set the random seed for reproducibility
# np.random.seed() has a range of [0, 2**32 - 1] for the seed value
# print(np.random.randint(0, 2**32 - 1)) # Uncomment here for the first run to be a statistical purist
SEED = 1687184344 # Obviously your print is going to be something different

np.random.seed(SEED)

# %%
# Load the data (House Prices dataset from Kaggle)

df = pd.read_csv("../data/house_prices/house_prices_train.csv")

# %%
# Take a peek at the data (Target Variable is SalePrice, self-descriptive)

df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## Non-important Preprocessing

# %%
# Super quick EDA by printing the correlation matrix of numeric features

df_numeric = df.select_dtypes(include=[np.number]).copy()

corr = df_numeric.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).format("{:.4f}")

# # Alternative printing if you prefer an image formatting:
# plt.figure(figsize=(25, 25))
# sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True)
# plt.title("Correlation Matrix of Numeric Features")
# plt.show()
# Out:
# <style type="text/css">
# #T_5c862_row0_col0, #T_5c862_row1_col1, #T_5c862_row2_col2, #T_5c862_row3_col3, #T_5c862_row4_col4, #T_5c862_row5_col5, #T_5c862_row6_col6, #T_5c862_row7_col7, #T_5c862_row8_col8, #T_5c862_row9_col9, #T_5c862_row10_col10, #T_5c862_row11_col11, #T_5c862_row12_col12, #T_5c862_row13_col13, #T_5c862_row14_col14, #T_5c862_row15_col15, #T_5c862_row16_col16, #T_5c862_row17_col17, #T_5c862_row18_col18, #T_5c862_row19_col19, #T_5c862_row20_col20, #T_5c862_row21_col21, #T_5c862_row22_col22, #T_5c862_row23_col23, #T_5c862_row24_col24, #T_5c862_row25_col25, #T_5c862_row26_col26, #T_5c862_row27_col27, #T_5c862_row28_col28, #T_5c862_row29_col29, #T_5c862_row30_col30, #T_5c862_row31_col31, #T_5c862_row32_col32, #T_5c862_row33_col33, #T_5c862_row34_col34, #T_5c862_row35_col35, #T_5c862_row36_col36, #T_5c862_row37_col37 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5c862_row0_col1, #T_5c862_row0_col5, #T_5c862_row0_col13, #T_5c862_row0_col16, #T_5c862_row1_col0, #T_5c862_row1_col33, #T_5c862_row2_col30, #T_5c862_row2_col35, #T_5c862_row2_col36, #T_5c862_row5_col0, #T_5c862_row6_col14, #T_5c862_row6_col35, #T_5c862_row8_col33, #T_5c862_row13_col0, #T_5c862_row14_col6, #T_5c862_row15_col22, #T_5c862_row16_col0, #T_5c862_row16_col30, #T_5c862_row21_col34, #T_5c862_row22_col15, #T_5c862_row24_col31, #T_5c862_row30_col2, #T_5c862_row30_col16, #T_5c862_row31_col24, #T_5c862_row32_col36, #T_5c862_row33_col1, #T_5c862_row33_col8, #T_5c862_row34_col21, #T_5c862_row35_col2, #T_5c862_row35_col6, #T_5c862_row36_col2, #T_5c862_row36_col32 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T
{
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5c862_row0_col15, #T_5c862_row1_col26, #T_5c862_row1_col31, #T_5c862_row4_col18, #T_5c862_row7_col21, #T_5c862_row10_col22, #T_5c862_row11_col20, #T_5c862_row11_col36, #T_5c862_row15_col0, #T_5c862_row17_col22, #T_5c862_row18_col4, #T_5c862_row20_col11, #T_5c862_row21_col7, #T_5c862_row22_col10, #T_5c862_row22_col17, #T_5c862_row26_col1, #T_5c862_row26_col34, #T_5c862_row31_col1, #T_5c862_row34_col26, #T_5c862_row36_col11 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5c862_row0_col21, #T_5c862_row1_col7, #T_5c862_row1_col23, #T_5c862_row2_col15, #T_5c862_row2_col32, #T_5c862_row3_col34, #T_5c862_row5_col10, #T_5c862_row7_col1, #T_5c862_row10_col5, #T_5c862_row10_col30, #T_5c862_row10_col33, #T_5c862_row12_col31, #T_5c862_row14_col32, #T_5c862_row15_col2, #T_5c862_row18_col28, #T_5c862_row21_col0, #T_5c862_row21_col30, #T_5c862_row22_col30, #T_5c862_row23_col1, #T_5c862_row23_col35, #T_5c862_row26_col35, #T_5c862_row28_col18, #T_5c862_row30_col10, #T_5c8

# %%
start_time = time.time()

# We are going to start by focusing only on 1 variable, GrLivArea (Squared Feet)
df_sel = df[["GrLivArea", "SalePrice"]].copy()

# And we standardize them to fit the linear regression
df_sel = (df_sel - np.mean(df_sel, axis=0)) / np.std(df_sel, axis=0)

X = df_sel[["GrLivArea"]]
y = df_sel["SalePrice"]

# %%
# TRAIN TEST SPLIT

# Shuffle the data so we don't have ordering artifacts
df_shuffled = df.sample(frac=1, random_state=168).reset_index(drop=True)
display(df)
display(df_shuffled)

# Split the data until the 80% mark (80 train, 20 test)
print(len(df)*0.8) # 1168

df_train, df_test = df_shuffled.iloc[:1168, :].copy(), df_shuffled.iloc[1168:, :].copy()

print(len(df_train), len(df_test)) # 1168 292

display(df_train.head(), df_test.head())
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      575          80       RL         70.0    10500   Pave   NaN      Reg
# 1      700         120       FV         59.0     4282   Pave  Pave      IR2
# 2     1244          20       RL        107.0    13891   Pave   NaN      Reg
# 3      566          70       RL         66.0     6858   Pave   NaN      Reg
# 4      520          70       RL         53.0    10918   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455   272          20       RL         73.0    39104   Pave   NaN      IR1
# 1456   992          70       RM        121.0    17671   Pave  Grvl      Reg
# 1457   302          60       RL         66.0    16226   Pave   NaN      IR3
# 1458  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# 1459  1280          50  C (all)         60.0     7500   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1458         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0        12   2007        WD         Normal     139000
# 1         7   2008        WD         Normal     196000
# 2         9   2006       New        Partial     465000
# 3         5   2010        WD         Normal     128000
# 4         6   2009        WD         Normal     234000
# ...     ...    ...       ...            ...        ...
# 1455      4   2008        WD         Normal     241500
# 1456     11   2009        WD         Normal     168000
# 1457      5   2007        WD         Normal     267000
# 1458      3   2006        WD         Normal      52500
# 1459      4   2010       COD        Abnorml      68400
#
# [1460 rows x 81 columns]
# 1168.0
# 1168 292
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   575          80       RL         70.0    10500   Pave   NaN      Reg
# 1   700         120       FV         59.0     4282   Pave  Pave      IR2
# 2  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 3   566          70       RL         66.0     6858   Pave   NaN      Reg
# 4   520          70       RL         53.0    10918   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0     12   2007        WD         Normal     139000
# 1      7   2008        WD         Normal     196000
# 2      9   2006       New        Partial     465000
# 3      5   2010        WD         Normal     128000
# 4      6   2009        WD         Normal     234000
#
# [5 rows x 81 columns]
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1168  1283          20       RL         61.0     8800   Pave   NaN      IR1
# 1169   561          20       RL          NaN    11341   Pave   NaN      IR1
# 1170   482          20       RL         72.0    11846   Pave   NaN      IR1
# 1171    29          20       RL         47.0    16321   Pave   NaN      IR1
# 1172   789          20       RM         50.0     6000   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1168         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1170         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1171         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1172         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1168      9   2009        WD         Normal     150500
# 1169      5   2010        WD         Normal     121500
# 1170      8   2006        WD         Normal     374000
# 1171     12   2006        WD         Normal     207500
# 1172      8   2008        WD         Normal     107900
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Univariate Linear Regression

# %%
# We are going to start by focusing only on 1 variable, GrLivArea (Squared Feet)

X_train, X_test = df_train[["GrLivArea", ]].copy(), df_test[["GrLivArea"]].copy()
y_train, y_test = df_train["SalePrice"].copy(), df_test["SalePrice"].copy()

print(X_train.shape, X_test.shape) # (1168, 1) (292, 1)
print(X_train, X_test)
# Out:
# (1168, 1) (292, 1)
#       GrLivArea
# 0          1109
# 1          1391
# 2          2076
# 3          1647
# 4          2080
# ...         ...
# 1163       1541
# 1164       1525
# 1165       1473
# 1166       1690
# 1167       2515
#
# [1168 rows x 1 columns]       GrLivArea
# 1168       1040
# 1169       1392
# 1170       1792
# 1171       1600
# 1172        901
# ...         ...
# 1455       1363
# 1456       1742
# 1457       2452
# 1458        693
# 1459       1128
#
# [292 rows x 1 columns]

# %%
linreg = LinearRegressionModel(
                learning_rate = 0.05,
                n_iterations = 10000,
                tol = 1e-6,
                verbose = True,
                standardize = True
            )

linreg.fit(X_train, y_train)

linreg.fit_closed_form_linreg(X_train, y_train)

linreg.fit_svd_linreg(X_train, y_train)

fit_params = linreg.get_params()
display(fit_params)
# Out:
# Iteration 1: loss (MSE) = 1.000e+00
# Iteration 2: loss (MSE) = 9.049e-01
# Iteration 3: loss (MSE) = 8.278e-01
# Iteration 4: loss (MSE) = 7.654e-01
# Iteration 5: loss (MSE) = 7.148e-01
# Iteration 6: loss (MSE) = 6.738e-01
# Iteration 7: loss (MSE) = 6.407e-01
# Iteration 8: loss (MSE) = 6.138e-01
# Iteration 9: loss (MSE) = 5.920e-01
# Iteration 10: loss (MSE) = 5.744e-01
# Iteration 11: loss (MSE) = 5.601e-01
# Iteration 12: loss (MSE) = 5.485e-01
# Iteration 13: loss (MSE) = 5.392e-01
# Iteration 14: loss (MSE) = 5.316e-01
# Iteration 15: loss (MSE) = 5.254e-01
# Iteration 16: loss (MSE) = 5.205e-01
# Iteration 17: loss (MSE) = 5.164e-01
# Iteration 81: loss (MSE) = 4.992e-01
# Iteration 82: loss (MSE) = 4.992e-01
# Iteration 83: loss (MSE) = 4.992e-01
# Iteration 84: loss (MSE) = 4.992e-01
# Iteration 85: loss (MSE) = 4.992e-01
# Iteration 86: loss (MSE) = 4.992e-01
# Iteration 87: loss (MSE) = 4.992e-01
# Iteration 88: loss (MSE) = 4.992e-01
# Iteration 89: loss (MSE) = 4.992e-01
# Iteration 90: loss (MSE) = 4.992e-01
# Iteration 91: loss (MSE) = 4.992e-01
# Iteration 92: loss (MSE) = 4.992e-01
# Iteration 93: loss (MSE) = 4.992e-01
# Iteration 94: loss (MSE) = 4.992e-01
# Iteration 95: loss (MSE) = 4.992e-01
# Iteration 96: loss (MSE) = 4.992e-01
# Iteration 97: loss (MSE) = 4.992e-01
# Iteration 98: loss (MSE) = 4.992e-01
# Iteration 99: loss (MSE) = 4.992e-01
# Iteration 100: loss (MSE) = 4.992e-01
# Iteration 101: loss (MSE) = 4.992e-01
# Iteration 102: loss (MSE) = 4.992e-01
# Iteration 103: loss (MSE) = 4.992e-01
# Iteration 104: loss (MSE) = 4.992e-01
# Iteration 105: loss (MSE) = 4.992e-01
# Iteration 106: loss (MSE) = 4.992e-01
# Iteration 107: loss (MSE) = 4.992e-01
# Iteration 108: loss (MSE) = 4.992e-01
# Iteration 109: loss (MSE) = 4.992e-01
# Iteration 110: loss (MSE) = 4.992e-01
# Iteration 111: loss (MSE) = 4.992e-01
# Iteration 112: loss (MSE) = 4.992e-01
# Iteration 113: loss (MSE) = 4.992e-01
# Iteration 114: loss (MSE) = 4.992e-01
# Iteration 115: loss (MSE) = 4.992e-01
# Iteration 116: loss (MSE) = 4.992e-01
# Iteration 117: loss (MSE) = 4.992e-01
# Iteration 118: loss (MSE) = 4.992e-01
# Iteration 119: loss (MSE) = 4.992e-01
# Iteration 120: loss (MSE) = 4.992e-01
# Iteration 121: loss (MSE) = 4.992e-01
# Iteration 122: loss (MSE) = 4.992e-01
# Iteration 123: loss (MSE) = 4.992e-01
# Iteration 124: loss (MSE) = 4.992e-01
# Iteration 125: loss (MSE) = 4.992e-01
# Iteration 126: loss (MSE) = 4.992e-01
# Iteration 127: loss (MSE) = 4.992e-01
# Iteration 128: loss (MSE) = 4.992e-01
# Iteration 129: loss (MSE) = 4.992e-01
# Iteration 130: loss (MSE) = 4.992e-01
# Iteration 131: loss (MSE) = 4.992e-01
# Iteration 132: loss (MSE) = 4.992e-01
# Iteration 133: loss (MSE) = 4.992e-01
# Iteration 134: loss (MSE) = 4.992e-01
# Iteration 135: loss (MSE) = 4.992e-01
# Iteration 136: loss (MSE) = 4.992e-01
# [[1109.]
#  [1391.]
#  [2076.]
#  ...
#  [1473.]
#  [1690.]
#  [2515.]]
# [[1.000e+00 1.109e+03]
#  [1.000e+00 1.391e+03]
#  [1.000e+00 2.076e+03]
#  ...
#  [1.000e+00 1.473e+03]
#  [1.000e+00 1.690e+03]
#  [1.000e+00 2.515e+03]]
# X.shape: (1168, 2) y.shape: (1168, 1)
# XtX.shape: (2, 2)
# eigvals.shape: (2,) V.shape: (2, 2)
# S.shape: (2,) V.shape: (2, 2)
# U.shape: (1168, 2)
# S_inv.shape: (2, 2)
# pseudo_inv.shape: (2, 1168)
# Betas.shape: (2, 1)
# {'beta_0': Array(18044.15768823, dtype=float64),
#  'beta_1': Array(108.03859363, dtype=float64),
#  'converged': 'Converged',
#  'n_iter': 136,
#  'final_loss': 0.499224242894264,
#  'closed_form_params': {'beta_0': Array(18044.05985916, dtype=float64),
#   'beta_1': Array(108.03865828, dtype=float64)},
#  'svd_params': {'beta_0': Array(18044.05985916, dtype=float64),
#   'beta_1': Array(108.03865828, dtype=float64)}}

# %%
print(f"Beta 0 using GD: {fit_params['beta_0']:,.2f}")
print(f"Beta 0 using closed-form: {fit_params['closed_form_params']['beta_0']:,.2f}")
print(f"Beta 0 using SVD: {fit_params['svd_params']['beta_0']:,.2f}")

print(f"\nBeta 1 using GD: {fit_params['beta_1']:,.2f}")
print(f"Beta 1 using closed-form: {fit_params['closed_form_params']['beta_1']:,.2f}")
print(f"Beta 1 using SVD: {fit_params['svd_params']['beta_1']:,.2f}")
# Out:
# Beta 0 using GD: 18,044.16
# Beta 0 using closed-form: 18,044.06
# Beta 0 using SVD: 18,044.06
#
# Beta 1 using GD: 108.04
# Beta 1 using closed-form: 108.04
# Beta 1 using SVD: 108.04

# %% [markdown]
# ## Multivariate Linear Regression

# %%
# And now we are going to try the multivariate case using both: 
# GrLivArea (Squared Feet) and OverallQual (Overall Quality)

# X_train, X_test = df_train[["GrLivArea", "OverallQual"]].copy(), df_test[["GrLivArea", "OverallQual"]].copy()
X_train, X_test = df_train[["GrLivArea", "OverallQual", "GarageCars", "FullBath"]].copy(), df_test[["GrLivArea", "OverallQual", "GarageCars", "FullBath"]].copy()
y_train, y_test = df_train["SalePrice"].copy(), df_test["SalePrice"].copy()

print(X_train.shape, X_test.shape) # (1168, 2) (292, 2)
# Out:
# (1168, 4) (292, 4)

# %%
linreg = LinearRegressionModel(
                learning_rate = 0.05,
                n_iterations = 10000,
                tol = 1e-6,
                verbose = True,
                standardize = True
            )

linreg.fit(X_train, y_train)

linreg.fit_closed_form_linreg(X_train, y_train)

linreg.fit_svd_linreg(X_train, y_train)

fit_params = linreg.get_params()
display(fit_params)
# Out:
# Iteration 1: loss (MSE) = 1.000e+00
# Iteration 2: loss (MSE) = 6.800e-01
# Iteration 3: loss (MSE) = 5.065e-01
# Iteration 4: loss (MSE) = 4.119e-01
# Iteration 5: loss (MSE) = 3.598e-01
# Iteration 6: loss (MSE) = 3.307e-01
# Iteration 7: loss (MSE) = 3.139e-01
# Iteration 8: loss (MSE) = 3.040e-01
# Iteration 9: loss (MSE) = 2.977e-01
# Iteration 10: loss (MSE) = 2.935e-01
# Iteration 11: loss (MSE) = 2.905e-01
# Iteration 12: loss (MSE) = 2.882e-01
# Iteration 13: loss (MSE) = 2.863e-01
# Iteration 14: loss (MSE) = 2.847e-01
# Iteration 15: loss (MSE) = 2.833e-01
# Iteration 16: loss (MSE) = 2.821e-01
# Iteration 17: loss (MSE) = 2.810e-01
# Iteration 18: loss (MSE) = 2.799e-01
# Iteration 19: loss (MSE) = 2.790e-01
# Iteration 20: loss (MSE) = 2.781e-01
# Iteration 21: loss (MSE) = 2.773e-01
# Iteration 22: loss (MSE) = 2.766e-01
# Iteration 23: loss (MSE) = 2.759e-01
# Iteration 24: loss (MSE) = 2.753e-01
# Iteration 25: loss (MSE) = 2.748e-01
# Iteration 26: loss (MSE) = 2.743e-01
# Iteration 27: loss (MSE) = 2.738e-01
# Iteration 28: loss (MSE) = 2.733e-01
# Iteration 29: loss (MSE) = 2.729e-01
# Iteration 30: loss (MSE) = 2.726e-01
# Iteration 31: loss (MSE) = 2.722e-01
# Iteration 32: loss (MSE) = 2.719e-01
# Iteration 33: loss (MSE) = 2.716e-01
# Iteration 34: loss (MSE) = 2.713e-01
# Iteration 35: loss (MSE) = 2.711e-01
# Iteration 36: loss (MSE) = 2.709e-01
# Iteration 37: loss (MSE) = 2.706e-01
# Iteration 38: loss (MSE) = 2.704e-01
# Iteration 39: loss (MSE) = 2.703e-01
# Iteration 40: loss (MSE) = 2.701e-01
# Iteration 41: loss (MSE) = 2.700e-01
# Iteration 42: loss (MSE) = 2.698e-01
# Iteration 43: loss (MSE) = 2.697e-01
# Iteration 44: loss (MSE) = 2.696e-01
# Iteration 45: loss (MSE) = 2.695e-01
# Iteration 46: loss (MSE) = 2.694e-01
# Iteration 47: loss (MSE) = 2.693e-01
# Iteration 48: loss (MSE) = 2.692e-01
# Iteration 49: loss (MSE) = 2.691e-01
# Iteration 50: loss (MSE) = 2.690e-01
# Iteration 51: loss (MSE) = 2.690e-01
# Iteration 52: loss (MSE) = 2.689e-01
# Iteration 53: loss (MSE) = 2.688e-01
# Iteration 54: loss (MSE) = 2.688e-01
# Iteration 55: loss (MSE) = 2.687e-01
# Iteration 56: loss (MSE) = 2.687e-01
# Iteration 57: loss (MSE) = 2.686e-01
# Iteration 58: loss (MSE) = 2.686e-01
# Iteration 59: loss (MSE) = 2.686e-01
# Iteration 60: loss (MSE) = 2.685e-01
# Iteration 61: loss (MSE) = 2.685e-01
# Iteration 62: loss (MSE) = 2.685e-01
# Iteration 63: loss (MSE) = 2.685e-01
# Iteration 64: loss (MSE) = 2.684e-01
# Iteration 65: loss (MSE) = 2.684e-01
# Iteration 66: loss (MSE) = 2.684e-01
# Iteration 67: loss (MSE) = 2.684e-01
# Iteration 68: loss (MSE) = 2.684e-01
# Iteration 69: loss (MSE) = 2.683e-01
# Iteration 70: loss (MSE) = 2.683e-01
# Iteration 71: loss (MSE) = 2.683e-01
# Iteration 72: loss (MSE) = 2.683e-01
# Iteration 73: loss (MSE) = 2.683e-01
# Iteration 74: loss (MSE) = 2.683e-01
# Iteration 75: loss (MSE) = 2.683e-01
# Iteration 76: loss (MSE) = 2.683e-01
# Iteration 77: loss (MSE) = 2.682e-01
# Iteration 78: loss (MSE) = 2.682e-01
# Iteration 79: loss (MSE) = 2.682e-01
# Iteration 80: loss (MSE) = 2.682e-01
# Iteration 81: loss (MSE) = 2.682e-01
# Iteration 82: loss (MSE) = 2.682e-01
# Iteration 83: loss (MSE) = 2.682e-01
# Iteration 84: loss (MSE) = 2.682e-01
# Iteration 85: loss (MSE) = 2.682e-01
# Iteration 86: loss (MSE) = 2.682e-01
# Iteration 87: loss (MSE) = 2.682e-01
# Iteration 88: loss (MSE) = 2.682e-01
# Iteration 89: loss (MSE) = 2.682e-01
# Iteration 90: loss (MSE) = 2.682e-01
# Iteration 91: loss (MSE) = 2.682e-01
# Iteration 92: loss (MSE) = 2.682e-01
# Iteration 93: loss (MSE) = 2.682e-01
# Iteration 94: loss (MSE) = 2.682e-01
# Iteration 95: loss (MSE) = 2.682e-01
# Iteration 96: loss (MSE) = 2.682e-01
# Iteration 97: loss (MSE) = 2.682e-01
# Iteration 98: loss (MSE) = 2.682e-01
# Iteration 99: loss (MSE) = 2.682e-01
# Iteration 100: loss (MSE) = 2.682e-01
# Iteration 101: loss (MSE) = 2.682e-01
# Iteration 102: loss (MSE) = 2.682e-01
# Iteration 103: loss (MSE) = 2.682e-01
# Iteration 104: loss (MSE) = 2.682e-01
# Iteration 105: loss (MSE) = 2.682e-01
# Iteration 106: loss (MSE) = 2.682e-01
# Iteration 107: loss (MSE) = 2.682e-01
# Iteration 108: loss (MSE) = 2.682e-01
# Iteration 109: loss (MSE) = 2.682e-01
# Iteration 110: loss (MSE) = 2.682e-01
# Iteration 111: loss (MSE) = 2.682e-01
# Iteration 112: loss (MSE) = 2.682e-01
# Iteration 113: loss (MSE) = 2.682e-01
# Iteration 114: loss (MSE) = 2.682e-01
# Iteration 115: loss (MSE) = 2.682e-01
# Iteration 116: loss (MSE) = 2.682e-01
# Iteration 117: loss (MSE) = 2.682e-01
# Iteration 118: loss (MSE) = 2.682e-01
# Iteration 119: loss (MSE) = 2.682e-01
# Iteration 120: loss (MSE) = 2.682e-01
# Iteration 121: loss (MSE) = 2.682e-01
# Iteration 122: loss (MSE) = 2.682e-01
# Iteration 123: loss (MSE) = 2.682e-01
# Iteration 124: loss (MSE) = 2.682e-01
# Iteration 125: loss (MSE) = 2.682e-01
# Iteration 126: loss (MSE) = 2.682e-01
# Iteration 127: loss (MSE) = 2.682e-01
# Iteration 128: loss (MSE) = 2.682e-01
# Iteration 129: loss (MSE) = 2.682e-01
# Iteration 130: loss (MSE) = 2.681e-01
# Iteration 131: loss (MSE) = 2.681e-01
# Iteration 132: loss (MSE) = 2.681e-01
# Iteration 133: loss (MSE) = 2.681e-01
# Iteration 134: loss (MSE) = 2.681e-01
# Iteration 135: loss (MSE) = 2.681e-01
# Iteration 136: loss (MSE) = 2.681e-01
# Iteration 137: loss (MSE) = 2.681e-01
# Iteration 138: loss (MSE) = 2.681e-01
# Iteration 139: loss (MSE) = 2.681e-01
# Iteration 140: loss (MSE) = 2.681e-01
# Iteration 141: loss (MSE) = 2.681e-01
# Iteration 142: loss (MSE) = 2.681e-01
# Iteration 143: loss (MSE) = 2.681e-01
# Iteration 144: loss (MSE) = 2.681e-01
# Iteration 145: loss (MSE) = 2.681e-01
# Iteration 146: loss (MSE) = 2.681e-01
# Iteration 147: loss (MSE) = 2.681e-01
# Iteration 148: loss (MSE) = 2.681e-01
# Iteration 149: loss (MSE) = 2.681e-01
# Iteration 150: loss (MSE) = 2.681e-01
# Iteration 151: loss (MSE) = 2.681e-01
# Iteration 152: loss (MSE) = 2.681e-01
# Iteration 153: loss (MSE) = 2.681e-01
# Iteration 154: loss (MSE) = 2.681e-01
# Iteration 155: loss (MSE) = 2.681e-01
# Iteration 156: loss (MSE) = 2.681e-01
# Iteration 157: loss (MSE) = 2.681e-01
# Iteration 158: loss (MSE) = 2.681e-01
# Iteration 159: loss (MSE) = 2.681e-01
# Iteration 160: loss (MSE) = 2.681e-01
# Iteration 161: loss (MSE) = 2.681e-01
# Iteration 162: loss (MSE) = 2.681e-01
# Iteration 163: loss (MSE) = 2.681e-01
# Iteration 164: loss (MSE) = 2.681e-01
# Iteration 165: loss (MSE) = 2.681e-01
# Iteration 166: loss (MSE) = 2.681e-01
# Iteration 167: loss (MSE) = 2.681e-01
# Iteration 168: loss (MSE) = 2.681e-01
# Iteration 169: loss (MSE) = 2.681e-01
# Iteration 170: loss (MSE) = 2.681e-01
# Iteration 171: loss (MSE) = 2.681e-01
# Iteration 172: loss (MSE) = 2.681e-01
# Iteration 173: loss (MSE) = 2.681e-01
# Iteration 174: loss (MSE) = 2.681e-01
# Iteration 175: loss (MSE) = 2.681e-01
# Iteration 176: loss (MSE) = 2.681e-01
# Iteration 177: loss (MSE) = 2.681e-01
# Iteration 178: loss (MSE) = 2.681e-01
# Iteration 179: loss (MSE) = 2.681e-01
# Iteration 180: loss (MSE) = 2.681e-01
# Iteration 181: loss (MSE) = 2.681e-01
# Iteration 182: loss (MSE) = 2.681e-01
# Iteration 183: loss (MSE) = 2.681e-01
# Iteration 184: loss (MSE) = 2.681e-01
# Iteration 185: loss (MSE) = 2.681e-01
# Iteration 186: loss (MSE) = 2.681e-01
# Iteration 187: loss (MSE) = 2.681e-01
# Iteration 188: loss (MSE) = 2.681e-01
# Iteration 189: loss (MSE) = 2.681e-01
# Iteration 190: loss (MSE) = 2.681e-01
# Iteration 191: loss (MSE) = 2.681e-01
# Iteration 192: loss (MSE) = 2.681e-01
# Iteration 193: loss (MSE) = 2.681e-01
# Iteration 194: loss (MSE) = 2.681e-01
# Iteration 195: loss (MSE) = 2.681e-01
# Iteration 196: loss (MSE) = 2.681e-01
# Iteration 197: loss (MSE) = 2.681e-01
# Iteration 198: loss (MSE) = 2.681e-01
# Iteration 199: loss (MSE) = 2.681e-01
# Iteration 200: loss (MSE) = 2.681e-01
# Iteration 201: loss (MSE) = 2.681e-01
# Iteration 202: loss (MSE) = 2.681e-01
# Iteration 203: loss (MSE) = 2.681e-01
# Iteration 204: loss (MSE) = 2.681e-01
# Iteration 205: loss (MSE) = 2.681e-01
# Iteration 206: loss (MSE) = 2.681e-01
# Iteration 207: loss (MSE) = 2.681e-01
# Iteration 208: loss (MSE) = 2.681e-01
# Iteration 209: loss (MSE) = 2.681e-01
# Iteration 210: loss (MSE) = 2.681e-01
# Iteration 211: loss (MSE) = 2.681e-01
# Iteration 212: loss (MSE) = 2.681e-01
# Iteration 213: loss (MSE) = 2.681e-01
# Iteration 214: loss (MSE) = 2.681e-01
# Iteration 215: loss (MSE) = 2.681e-01
# Iteration 216: loss (MSE) = 2.681e-01
# Iteration 217: loss (MSE) = 2.681e-01
# Iteration 218: loss (MSE) = 2.681e-01
# Iteration 219: loss (MSE) = 2.681e-01
# Iteration 220: loss (MSE) = 2.681e-01
# Iteration 221: loss (MSE) = 2.681e-01
# Iteration 222: loss (MSE) = 2.681e-01
# Iteration 223: loss (MSE) = 2.681e-01
# Iteration 224: loss (MSE) = 2.681e-01
# Iteration 225: loss (MSE) = 2.681e-01
# Iteration 226: loss (MSE) = 2.681e-01
# Iteration 227: loss (MSE) = 2.681e-01
# Iteration 228: loss (MSE) = 2.681e-01
# Iteration 229: loss (MSE) = 2.681e-01
# Iteration 230: loss (MSE) = 2.681e-01
# Iteration 231: loss (MSE) = 2.681e-01
# Iteration 232: loss (MSE) = 2.681e-01
# Iteration 233: loss (MSE) = 2.681e-01
# Iteration 234: loss (MSE) = 2.681e-01
# Iteration 235: loss (MSE) = 2.681e-01
# Iteration 236: loss (MSE) = 2.681e-01
# Iteration 237: loss (MSE) = 2.681e-01
# Iteration 238: loss (MSE) = 2.681e-01
# Iteration 239: loss (MSE) = 2.681e-01
# Iteration 240: loss (MSE) = 2.681e-01
# Iteration 241: loss (MSE) = 2.681e-01
# Iteration 242: loss (MSE) = 2.681e-01
# Iteration 243: loss (MSE) = 2.681e-01
# Iteration 244: loss (MSE) = 2.681e-01
# Iteration 245: loss (MSE) = 2.681e-01
# Iteration 246: loss (MSE) = 2.681e-01
# Iteration 247: loss (MSE) = 2.681e-01
# Iteration 248: loss (MSE) = 2.681e-01
# Iteration 249: loss (MSE) = 2.681e-01
# Iteration 250: loss (MSE) = 2.681e-01
# Iteration 251: loss (MSE) = 2.681e-01
# Iteration 252: loss (MSE) = 2.681e-01
# Iteration 253: loss (MSE) = 2.681e-01
# Iteration 254: loss (MSE) = 2.681e-01
# Iteration 255: loss (MSE) = 2.681e-01
# Iteration 256: loss (MSE) = 2.681e-01
# Iteration 257: loss (MSE) = 2.681e-01
# Iteration 258: loss (MSE) = 2.681e-01
# Iteration 259: loss (MSE) = 2.681e-01
# Iteration 260: loss (MSE) = 2.681e-01
# Iteration 261: loss (MSE) = 2.681e-01
# Iteration 262: loss (MSE) = 2.681e-01
# Iteration 263: loss (MSE) = 2.681e-01
# Iteration 264: loss (MSE) = 2.681e-01
# Iteration 265: loss (MSE) = 2.681e-01
# Iteration 266: loss (MSE) = 2.681e-01
# Iteration 267: loss (MSE) = 2.681e-01
# Iteration 268: loss (MSE) = 2.681e-01
# Iteration 269: loss (MSE) = 2.681e-01
# Iteration 270: loss (MSE) = 2.681e-01
# Iteration 271: loss (MSE) = 2.681e-01
# Iteration 272: loss (MSE) = 2.681e-01
# Iteration 273: loss (MSE) = 2.681e-01
# Iteration 274: loss (MSE) = 2.681e-01
# Iteration 275: loss (MSE) = 2.681e-01
# Iteration 276: loss (MSE) = 2.681e-01
# Iteration 277: loss (MSE) = 2.681e-01
# Iteration 278: loss (MSE) = 2.681e-01
# Iteration 279: loss (MSE) = 2.681e-01
# Iteration 280: loss (MSE) = 2.681e-01
# Iteration 281: loss (MSE) = 2.681e-01
# Iteration 282: loss (MSE) = 2.681e-01
# Iteration 283: loss (MSE) = 2.681e-01
# Iteration 284: loss (MSE) = 2.681e-01
# Iteration 285: loss (MSE) = 2.681e-01
# Iteration 286: loss (MSE) = 2.681e-01
# Iteration 287: loss (MSE) = 2.681e-01
# Iteration 288: loss (MSE) = 2.681e-01
# Iteration 289: loss (MSE) = 2.681e-01
# Iteration 290: loss (MSE) = 2.681e-01
# Iteration 291: loss (MSE) = 2.681e-01
# Iteration 292: loss (MSE) = 2.681e-01
# Iteration 293: loss (MSE) = 2.681e-01
# Iteration 294: loss (MSE) = 2.681e-01
# Iteration 295: loss (MSE) = 2.681e-01
# Iteration 296: loss (MSE) = 2.681e-01
# Iteration 297: loss (MSE) = 2.681e-01
# Iteration 298: loss (MSE) = 2.681e-01
# Iteration 299: loss (MSE) = 2.681e-01
# Iteration 300: loss (MSE) = 2.681e-01
# Iteration 301: loss (MSE) = 2.681e-01
# Iteration 302: loss (MSE) = 2.681e-01
# Iteration 303: loss (MSE) = 2.681e-01
# Iteration 304: loss (MSE) = 2.681e-01
# Iteration 305: loss (MSE) = 2.681e-01
# Iteration 306: loss (MSE) = 2.681e-01
# Iteration 307: loss (MSE) = 2.681e-01
# Iteration 308: loss (MSE) = 2.681e-01
# Iteration 309: loss (MSE) = 2.681e-01
# Iteration 310: loss (MSE) = 2.681e-01
# Iteration 311: loss (MSE) = 2.681e-01
# Iteration 312: loss (MSE) = 2.681e-01
# Iteration 313: loss (MSE) = 2.681e-01
# Iteration 314: loss (MSE) = 2.681e-01
# Iteration 315: loss (MSE) = 2.681e-01
# Iteration 316: loss (MSE) = 2.681e-01
# Iteration 317: loss (MSE) = 2.681e-01
# Iteration 318: loss (MSE) = 2.681e-01
# Iteration 319: loss (MSE) = 2.681e-01
# Iteration 320: loss (MSE) = 2.681e-01
# Iteration 321: loss (MSE) = 2.681e-01
# [[1.109e+03 5.000e+00 1.000e+00 1.000e+00]
#  [1.391e+03 7.000e+00 2.000e+00 2.000e+00]
#  [2.076e+03 1.000e+01 3.000e+00 2.000e+00]
#  ...
#  [1.473e+03 5.000e+00 1.000e+00 1.000e+00]
#  [1.690e+03 6.000e+00 2.000e+00 2.000e+00]
#  [2.515e+03 6.000e+00 2.000e+00 3.000e+00]]
# [[1.000e+00 1.109e+03 5.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 1.391e+03 7.000e+00 2.000e+00 2.000e+00]
#  [1.000e+00 2.076e+03 1.000e+01 3.000e+00 2.000e+00]
#  ...
#  [1.000e+00 1.473e+03 5.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 1.690e+03 6.000e+00 2.000e+00 2.000e+00]
#  [1.000e+00 2.515e+03 6.000e+00 2.000e+00 3.000e+00]]
# X.shape: (1168, 5) y.shape: (1168, 1)
# XtX.shape: (5, 5)
# eigvals.shape: (5,) V.shape: (5, 5)
# S.shape: (5,) V.shape: (5, 5)
# U.shape: (1168, 5)
# S_inv.shape: (5, 5)
# pseudo_inv.shape: (5, 1168)
# Betas.shape: (5, 1)
# {'beta_0': Array(-98936.05047602, dtype=float64),
#  'beta_1': Array(52.69664682, dtype=float64),
#  'beta_2': Array(27097.21745759, dtype=float64),
#  'beta_3': Array(21349.86490647, dtype=float64),
#  'beta_4': Array(-1702.22081411, dtype=float64),
#  'converged': 'Converged',
#  'n_iter': 321,
#  'final_loss': 0.2681483644438423,
#  'closed_form_params': {'beta_0': Array(-98936.19499883, dtype=float64),
#   'beta_1': Array(52.69663136, dtype=float64),
#   'beta_2': Array(27097.28031199, dtype=float64),
#   'beta_3': Array(21349.79361888, dtype=float64),
#   'beta_4': Array(-1702.27787876, dtype=float64)},
#  'svd_params': {'beta_0': Array(-98936.19394482, dtype=float64),
#   'beta_1': Array(52.69663133, dtype=float64),
#   'beta_2': Array(27097.2801511, dtype=float64),
#   'beta_3': Array(21349.79366824, dtype=float64),
#   'beta_4': Array(-1702.27792536, dtype=float64)}}

# %%
print(f"Beta 0 using GD: {fit_params['beta_0']:,.2f}")
print(f"Beta 0 using closed-form: {fit_params['closed_form_params']['beta_0']:,.2f}")
print(f"Beta 0 using SVD: {fit_params['svd_params']['beta_0']:,.2f}")

print(f"\nBeta 1 using GD: {fit_params['beta_1']:,.2f}")
print(f"Beta 1 using closed-form: {fit_params['closed_form_params']['beta_1']:,.2f}")
print(f"Beta 1 using SVD: {fit_params['svd_params']['beta_1']:,.2f}")

print(f"\nBeta 2 using GD: {fit_params['beta_2']:,.2f}")
print(f"Beta 2 using closed-form: {fit_params['closed_form_params']['beta_2']:,.2f}")
print(f"Beta 2 using SVD: {fit_params['svd_params']['beta_2']:,.2f}")
# Out:
# Beta 0 using GD: -98,936.05
# Beta 0 using closed-form: -98,936.19
# Beta 0 using SVD: -98,936.19
#
# Beta 1 using GD: 52.70
# Beta 1 using closed-form: 52.70
# Beta 1 using SVD: 52.70
#
# Beta 2 using GD: 27,097.22
# Beta 2 using closed-form: 27,097.28
# Beta 2 using SVD: 27,097.28

# %%
end_time = time.time()

print(f"Total execution time: {end_time - start_time:.4f} seconds")
# Out:
# Total execution time: 5.7940 seconds
